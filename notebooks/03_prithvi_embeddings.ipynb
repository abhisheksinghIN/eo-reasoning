# %% [markdown]
# # 03 · Prithvi temporal embeddings
#
# Extract one learned representation per temporal frame.

# %%
from tools.geofm_tools import run_prithvi_temporal
result = run_prithvi_temporal(paths)
result["summary"]
