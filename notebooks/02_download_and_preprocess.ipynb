# %% [markdown]
# # 02 · Download and preprocess
#
# Download three patches and create a Prithvi tensor.

# %%
from data.sentinel2 import download_temporal_stack
from data.preprocessing import prepare_prithvi_tensor
bbox = [11.25, 46.40, 11.40, 46.55]
dates = ["2026-06-01", "2026-06-15", "2026-07-01"]  # replace with actual scene dates
paths = download_temporal_stack(bbox, dates)
tensor, raw_frames = prepare_prithvi_tensor(paths)
tensor.shape
