# %% [markdown]
# # 04 · Evidence pipeline
#
# Run the deterministic analysis before involving an LLM.

# %%
from tools.pipeline import analyze_temporal_aoi
evidence = analyze_temporal_aoi(bbox=bbox, dates=dates)
evidence
