# %% [markdown]
# # 05 · Qwen3 tool-calling agent
#
# Run after starting Ollama and pulling Qwen3.

# %%
from agent.agent import EOAgent
agent = EOAgent(model="qwen3")
result = agent.run("For bbox [11.25,46.40,11.40,46.55], search Sentinel-2 from 2026-06-01 to 2026-07-31. Do not invent observations.")
print(result["answer"])
result["trace"]
